# %%
import pandas as pd

# %%
balanced_df = pd.read_csv(r"../data/balanced_amazon_reviews.csv")

# %%
balanced_df
# Out:
#         label                     title  \
# 0           0          Substandard Size
# 1           1        "I never grew up."
# 2           1         My favorite book!
# 3           1       The Perfect Husband
# 4           0  The picture looks better
# ...       ...                       ...
# 199995      1        Lots of options...
# 199996      1                   Sublime
# 199997      0   nice build poor quality
# 199998      0         Good For Kindling
# 199999      1              All Grown Up
#
#                                                   content
# 0       The width of this product is much smaller than...
# 1       Mickey Rooney's 1993 autobiography is equally ...
# 2       I have always loved this story and read it eve...
# 3       Lisa Gardner is a new author for me so imagine...
# 4       The ring was pretty chincy once I saw it in pe...
# ...                                                   ...
# 199995  I found the All-in-1 Grooming System to be a p...
# 199996  I owned this album as a vinyl LP when it came ...
# 199997  problems consist of random failures first mous...
# 199998  My sister gave me this book after the birth of...
# 199999  The Really cool thing about Savatage , and thi...
#
# [200000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(balanced_df, test_size=0.2, stratify=balanced_df['label'], random_state=42)
val_df, test_df = train_test_split(balanced_df, test_size=0.5, stratify=balanced_df['label'], random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')

X_train = vectorizer.fit_transform(train_df['content'])
X_val = vectorizer.transform(val_df['content'])
X_test = vectorizer.transform(test_df['content'])


y_train = train_df['label']
y_val = val_df['label']
y_test = test_df['label']

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import classification_report

y_pred = clf.predict(X_val)
print(classification_report(y_val, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8724    0.8670    0.8697     50000
#            1     0.8679    0.8732    0.8705     50000
#
#     accuracy                         0.8701    100000
#    macro avg     0.8701    0.8701    0.8701    100000
# weighted avg     0.8701    0.8701    0.8701    100000
